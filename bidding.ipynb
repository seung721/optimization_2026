# %%
Bidding_A = "Bidding_A.csv"
Bidding_B = "Bidding_B.csv"
Bidding_H = "Bidding_H.csv"
Bidding_I = "Bidding_I.csv"
Bidding_L = "Bidding_L.csv"
OriginalPrice = "Bidding_OriginalPrice.csv"
Target = "Bidding_TargetVolume.csv"
Tier = "Bidding_Tier.csv"

# %%
# Out:
# Bidding_A.csv
